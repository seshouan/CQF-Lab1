# %%
# Ignore warnings - optional
import warnings
warnings.filterwarnings('ignore')
# Import data manipulation libraries
import numpy as np
import pandas as pd
# Import yahoo finance library
import yfinance as yf
# Import cufflinks for visualization
import cufflinks as cf
cf.set_config_file(offline=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.27.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.27.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# Fetch the data by specifying the number of period
df1 = yf.download('AAPL', period='5d', progress=False)

# Display the first five rows of the dataframe to check the results.
df1
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2024-01-30  190.940002  191.800003  187.470001  188.039993  188.039993
# 2024-01-31  187.039993  187.100006  184.350006  184.399994  184.399994
# 2024-02-01  183.990005  186.949997  183.820007  186.860001  186.860001
# 2024-02-02  179.860001  187.330002  179.250000  185.850006  185.850006
# 2024-02-05  188.149994  189.250000  185.839996  187.679993  187.679993
#
#                Volume
# Date
# 2024-01-30   55859400
# 2024-01-31   55467800
# 2024-02-01   64885400
# 2024-02-02  102518000
# 2024-02-05   68862037

# %%
# Fetch data by specifying the the start and end dates
df2 = yf.download('AAPL', start='2024-01-01', end='2024-01-31', progress=False)

# Display the first five rows of the dataframe to check the results.
df2.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2024-01-02  187.149994  188.440002  183.889999  185.639999  185.639999
# 2024-01-03  184.220001  185.880005  183.429993  184.250000  184.250000
# 2024-01-04  182.149994  183.089996  180.880005  181.910004  181.910004
# 2024-01-05  181.990005  182.759995  180.169998  181.179993  181.179993
# 2024-01-08  182.089996  185.600006  181.500000  185.559998  185.559998
#
#               Volume
# Date
# 2024-01-02  82488700
# 2024-01-03  58414500
# 2024-01-04  71983600
# 2024-01-05  62303300
# 2024-01-08  59144500

# %%
# Display last five rows
df2.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2024-01-24  195.419998  196.380005  194.339996  194.500000  194.500000
# 2024-01-25  195.220001  196.270004  193.110001  194.169998  194.169998
# 2024-01-26  194.270004  194.759995  191.940002  192.419998  192.419998
# 2024-01-29  192.009995  192.199997  189.580002  191.729996  191.729996
# 2024-01-30  190.940002  191.800003  187.470001  188.039993  188.039993
#
#               Volume
# Date
# 2024-01-24  53631300
# 2024-01-25  54822100
# 2024-01-26  44594000
# 2024-01-29  47145600
# 2024-01-30  55859400

# %%
# Fetch data for year to date (YTD)
df3 = yf.download('AAPL', period='ytd', progress=False)

# Display the last five rows of the dataframe to check the results.
df3.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2024-01-30  190.940002  191.800003  187.470001  188.039993  188.039993
# 2024-01-31  187.039993  187.100006  184.350006  184.399994  184.399994
# 2024-02-01  183.990005  186.949997  183.820007  186.860001  186.860001
# 2024-02-02  179.860001  187.330002  179.250000  185.850006  185.850006
# 2024-02-05  188.149994  189.250000  185.839996  187.679993  187.679993
#
#                Volume
# Date
# 2024-01-30   55859400
# 2024-01-31   55467800
# 2024-02-01   64885400
# 2024-02-02  102518000
# 2024-02-05   68862037

# %%
# Specify stocks
# https://en.wikipedia.org/wiki/Dow_Jones_Industrial_Average
dow_stocks = ['UNH', 'GS', 'HD', 'AMGN', 'MCD']

# Fetch data for multiple stocks at once
df4 = yf.download(dow_stocks, period='ytd', progress=False)['Adj Close']
# Display dataframe
df4.tail()
# Out:
# Ticker            AMGN          GS          HD         MCD         UNH
# Date
# 2024-01-30  314.619995  386.869995  357.100006  294.649994  503.609985
# 2024-01-31  314.260010  384.010010  352.959991  292.720001  511.739990
# 2024-02-01  324.559998  383.850006  360.070007  298.079987  507.140015
# 2024-02-02  323.190002  387.859985  357.230011  297.049988  510.230011
# Out:
#                                  Open        High         Low       Close  \
# Datetime
# 2024-01-30 09:30:00-05:00  190.940002  191.110001  190.679993  191.059998
# 2024-01-30 09:31:00-05:00  191.070007  191.350006  190.949997  191.320007
# 2024-01-30 09:32:00-05:00  191.330002  191.479996  191.080002  191.095001
# 2024-01-30 09:33:00-05:00  191.100006  191.570007  191.070007  191.570007
# 2024-01-30 09:34:00-05:00  191.565002  191.800003  191.490005  191.550995
# ...                               ...         ...         ...         ...
# 2024-02-05 15:55:00-05:00  188.115005  188.179901  187.975006  188.169998
# 2024-02-05 15:56:00-05:00  188.179993  188.289993  188.151001  188.210007
# 2024-02-05 15:57:00-05:00  188.210007  188.229996  187.990005  188.009995
# 2024-02-05 15:58:00-05:00  188.020004  188.104996  187.990005  188.020004
# 2024-02-05 15:59:00-05:00  188.009995  188.020004  187.639999  187.669998
#
#                             Adj Close   Volume
# Datetime
# 2024-01-30 09:30:00-05:00  191.059998  1365044
# 2024-01-30 09:31:00-05:00  191.320007   276922
# 2024-01-30 09:32:00-05:00  191.095001   245828
# 2024-01-30 09:33:00-05:00  191.570007   206399
# 2024-01-30 09:34:00-05:00  191.550995   206852
# ...                               ...      ...
# 2024-02-05 15:55:00-05:00  188.169998   265647
# 2024-02-05 15:56:00-05:00  188.210007   257217
# 2024-02-05 15:57:00-05:00  188.009995   253759
# 2024-02-05 15:58:00-05:00  188.020004   305092
# 2024-02-05 15:59:00-05:00  187.669998  1023528
#
# [1948 rows x 6 columns]

# %%
# Ticker object
spy = yf.Ticker('SPY')

# %%
spy.options
# Out:
# ('2024-02-05',
#  '2024-02-06',
#  '2024-02-07',
#  '2024-02-08',
#  '2024-02-09',
#  '2024-02-12',
#  '2024-02-13',
#  '2024-02-14',
#  '2024-02-15',
#  '2024-02-16',
#  '2024-02-23',
#  '2024-02-29',
#  '2024-03-01',
#  '2024-03-08',
#  '2024-03-15',
#  '2024-03-22',
#  '2024-03-28',
#  '2024-04-19',
#  '2024-04-30',
#  '2024-05-17',
#  '2024-05-31',
#  '2024-06-21',
#  '2024-06-28',
#  '2024-07-19',
#  '2024-07-31',
#  '2024-08-16',
#  '2024-09-20',
#  '2024-09-30',
#  '2024-12-20',
#  '2024-12-31',
#  '2025-01-17',
#  '2025-03-21',
#  '2025-06-20',
#  '2025-12-19',
#  '2026-01-16',
#  '2026-12-18')

# %%
# Use option chain method
spy.option_chain
# Out:
# <bound method Ticker.option_chain of yfinance.Ticker object <SPY>>

# %%
# Get SPY option chain for March 28th expiration
# https://finance.yahoo.com/quote/SPY240328C00475000?p=SPY240328C00475000
options = spy.option_chain('2024-03-28')
options
# Out:
# Options(calls=         contractSymbol             lastTradeDate  strike  lastPrice     bid  \
# 0    SPY240328C00275000 2024-02-01 17:47:43+00:00   275.0     213.81  218.91
# 1    SPY240328C00280000 2023-12-18 15:43:51+00:00   280.0     195.66  195.92
# 2    SPY240328C00285000 2023-12-12 17:57:46+00:00   285.0     180.12  193.83
# 3    SPY240328C00290000 2024-01-25 19:24:16+00:00   290.0     198.25  203.99
# 4    SPY240328C00295000 2023-12-12 17:24:26+00:00   295.0     170.55  183.94
# ..                  ...                       ...     ...        ...     ...
 'quoteSourceName': 'Nasdaq Real Time Price', 'triggerable': True, 'customPriceAlertConfidence': 'HIGH', 'currency': 'USD', 'marketState': 'POST', 'regularMarketChangePercent': -0.364118, 'regularMarketPrice': 492.55, 'exchange': 'PCX', 'shortName': 'SPDR S&P 500', 'longName': 'SPDR S&P 500 ETF Trust', 'messageBoardId': 'finmb_6160262', 'exchangeTimezoneName': 'America/New_York', 'exchangeTimezoneShortName': 'EST', 'gmtOffSetMilliseconds': -18000000, 'market': 'us_market', 'esgPopulated': False, 'firstTradeDateMilliseconds': 728317800000, 'priceHint': 2, 'postMarketChangePercent': -0.048724037, 'postMarketTime': 1707169862, 'postMarketPrice': 492.31, 'postMarketChange': -0.23999023, 'regularMarketChange': -1.80002, 'regularMarketTime': 1707166800, 'regularMarketDayHigh': 494.3778, 'regularMarketDayRange': '490.23 - 494.3778', 'regularMarketDayLow': 490.23, 'regularMarketVolume': 67959347, 'regularMarketPreviousClose': 494.35, 'bid': 492.62, 'ask': 492.59, 'bidSize': 12, 'askSize': 8, 'fullExchangeName': 'NYSEArca', 'financialCurrency': 'USD', 'regularMarketOpen': 493.695, 'averageDailyVolume3Month': 77731491, 'averageDailyVolume10Day': 79371340, 'fiftyTwoWeekLowChange': 111.899994, 'fiftyTwoWeekLowChangePercent': 0.29397082, 'fiftyTwoWeekRange': '380.65 - 496.05', 'fiftyTwoWeekHighChange': -3.5, 'fiftyTwoWeekHighChangePercent': -0.0070557403, 'fiftyTwoWeekLow': 380.65, 'fiftyTwoWeekHigh': 496.05, 'fiftyTwoWeekChangePercent': 20.623184, 'trailingAnnualDividendRate': 5.662, 'trailingPE': 24.811949, 'trailingAnnualDividendYield': 0.011453424, 'dividendYield': 1.4, 'ytdReturn': 26.13868, 'trailingThreeMonthReturns': 11.64447, 'trailingThreeMonthNavReturns': 11.64447, 'netAssets': 497007821000.0, 'epsTrailingTwelveMonths': 19.851322, 'sharesOutstanding': 917782016, 'bookValue': 429.22, 'fiftyDayAverage': 471.4336, 'fiftyDayAverageChange': 21.116394, 'fiftyDayAverageChangePercent': 0.044791874, 'twoHundredDayAverage': 443.1283, 'twoHundredDayAverageChange': 49.42169, 'twoHundredDayAverageChangePercent': 0.11152908, 'netExpenseRatio': 0.0945, 'marketCap': 452053532672, 'priceToBook': 1.1475466, 'sourceInterval': 15, 'exchangeDataDelayedBy': 0, 'tradeable': False, 'cryptoTradeable': False, 'symbol': 'SPY'})

# %%
# Filter calls for strike above 490
df7 = options.calls[options.calls['strike']>490]

# Check the filtered output
df7.iloc[:,:7]
# Out:
#          contractSymbol             lastTradeDate  strike  lastPrice    bid  \
# 124  SPY240328C00491000 2024-02-05 17:47:48+00:00   491.0      11.44  10.87
# 125  SPY240328C00492000 2024-02-05 21:09:18+00:00   492.0      10.36  10.24
# 126  SPY240328C00493000 2024-02-05 21:14:16+00:00   493.0       9.71   9.63
# 127  SPY240328C00494000 2024-02-05 20:40:25+00:00   494.0       9.66   9.03
# 128  SPY240328C00495000 2024-02-05 21:00:35+00:00   495.0       8.40   8.46
# 129  SPY240328C00496000 2024-02-05 17:30:01+00:00   496.0       8.31   7.91
# 130  SPY240328C00497000 2024-02-05 20:38:03+00:00   497.0       8.00   7.39
# 131  SPY240328C00498000 2024-02-05 20:55:31+00:00   498.0       7.41   6.88
# 166  SPY240328C00545000 2024-02-05 18:18:12+00:00   545.0       0.12   0.09
# 167  SPY240328C00550000 2024-02-05 19:50:29+00:00   550.0       0.09   0.06
# 168  SPY240328C00555000 2024-02-05 19:27:13+00:00   555.0       0.05   0.04
# 169  SPY240328C00560000 2024-02-05 17:30:37+00:00   560.0       0.05   0.03
# 170  SPY240328C00565000 2024-02-05 15:09:02+00:00   565.0       0.04   0.03
# 171  SPY240328C00570000 2024-02-02 20:47:42+00:00   570.0       0.03   0.02
# 172  SPY240328C00575000 2024-02-05 20:57:20+00:00   575.0       0.02   0.02
#
#        ask    change
# 124  10.94 -1.660001
# 125  10.30 -1.330000
# 126   9.69 -2.550000
# 127   9.09 -0.910000
# 128   8.53 -1.640000
# 129   7.98 -1.070000
# 130   7.45 -1.229999
# 131   6.94 -0.680000
# 132   6.47 -1.240000
# 133   6.01 -1.290000
# 134   5.57 -1.270000
# 135   5.17 -1.020000
# 136   4.78 -1.400000
# 137   4.42 -1.190000
# 138   4.08 -1.500000
# 139   3.76 -1.080000
# 140   3.46 -1.130000
# 141   3.18 -0.940000
# 142   2.92 -0.460000
# 143   2.68 -0.690000
# 144   2.45 -1.050000
# 145   2.25 -1.120000
# 146   2.05 -0.620000
# 147   1.87 -0.170000
# 148   1.71 -0.720000
# 149   1.56 -0.790000
# 150   1.41 -0.520000
# 151   1.28 -0.660000
# 152   1.17 -0.500000
# 153   1.05 -0.370000
# 154   0.95 -0.400000
# 155   0.86 -0.440000
# 156   0.78 -0.070000
# 157   0.71 -0.300000
# 158   0.64 -0.200000
# 159   0.58 -0.190000
# 160   0.52 -0.310000
# 161   0.47  0.000000
# 162   0.43 -0.280000
# 163   0.39 -0.160000
# 164   0.24 -0.090000
# 165   0.15 -0.120000
# 166   0.11 -0.050000
# 167   0.08 -0.020000
# 168   0.06 -0.040000
# 169   0.05  0.000000
# 170   0.05  0.020000
# 171   0.04  0.000000
# 172   0.04 -0.020000

# %%
# Read data from wikipedia
nifty50 = pd.read_html('https://en.wikipedia.org/wiki/NIFTY_50')[2].Symbol.to_list()

# Read five symbols
nifty50[:5]
# Out:
# ['ADANIENT', 'ADANIPORTS', 'APOLLOHOSP', 'ASIANPAINT', 'AXISBANK']

# %%
# Import & create database
import sqlalchemy
engine = sqlalchemy.create_engine('sqlite:///Test')

# %%
# Fetch data from yahoo using list comprehension
data = [yf.download(symbol+'.NS', period='250d', progress=False).reset_index() for symbol in nifty50]

# save it to database
for frame, symbol in zip(data, nifty50):
    frame.to_sql(symbol, engine, if_exists='replace', index=False)

# %%
# Query from database
result = pd.read_sql_query('SELECT * FROM "ADANIENT" WHERE DATE > "2024-01-01"', engine, index_col='Date')

# Display the results
result.tail()
# Out:
#                                    Open         High          Low  \
# Date
# 2024-01-30 00:00:00.000000  3081.000000  3129.899902  3020.899902
# 2024-01-31 00:00:00.000000  3092.750000  3151.699951  3072.399902
# 2024-02-01 00:00:00.000000  3156.899902  3236.949951  3083.050049
# 2024-02-02 00:00:00.000000  3184.949951  3208.500000  3140.000000
# 2024-02-05 00:00:00.000000  3170.000000  3229.399902  3151.449951
#
#                                   Close    Adj Close   Volume
# Date
# 2024-01-30 00:00:00.000000  3091.100098  3091.100098  3115506
# 2024-01-31 00:00:00.000000  3142.000000  3142.000000  2671051
# 2024-02-01 00:00:00.000000  3153.500000  3153.500000  4686595
# 2024-02-02 00:00:00.000000  3157.449951  3157.449951  2708695
# 2024-02-05 00:00:00.000000  3173.449951  3173.449951  2190936

# %%
# Query from database
df = pd.read_sql_query('SELECT * FROM "TITAN"', engine, index_col='Date')

# Convert to datetime format
df.index = pd.to_datetime(df.index)

# %%
# Get first few days of data
df.first('3D')
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2023-01-31  2347.000000  2386.449951  2335.649902  2377.149902  2369.473145
# 2023-02-01  2408.550049  2409.800049  2300.050049  2345.899902  2338.323975
# 2023-02-02  2341.050049  2385.000000  2269.600098  2308.100098  2300.646240
#
#              Volume
# Date
# 2023-01-31  1252600
# 2023-02-01  1521514
# 2023-02-02  1788381

# %%
# Get last few days of data
df.last('3D')
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2024-02-05  3612.949951  3624.649902  3534.899902  3552.050049  3552.050049
#
#              Volume
# Date
# 2024-02-05  1771380

# %%
# Filter based on column
df.filter(['Close'])
# Out:
#                   Close
# Date
# 2023-01-31  2377.149902
# 2023-02-01  2345.899902
# 2023-02-02  2308.100098
# 2023-02-03  2463.100098
# 2023-02-06  2458.000000
# ...                 ...
# 2024-01-30  3735.750000
# 2024-01-31  3697.550049
# 2024-02-01  3627.449951
# 2024-02-02  3612.399902
# 2024-02-05  3552.050049
#
# [250 rows x 1 columns]

# %%
# Filter based on row or index
df.filter(like='2023-10-23', axis=0)
# Out:
#                    Open         High          Low    Close  Adj Close  Volume
# Date
# 2023-10-23  3246.199951  3274.949951  3209.699951  3219.75    3219.75  566920

# %%
# Query for a specific condition. Ex: Close price > 3800
df.query('Close>3800')
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2024-01-16  3758.850098  3858.000000  3756.000000  3820.300049  3820.300049
# 2024-01-17  3818.949951  3855.000000  3800.000000  3830.050049  3830.050049
# 2024-01-19  3742.199951  3861.500000  3740.699951  3810.600098  3810.600098
# 2024-01-22  3810.600098  3810.600098  3810.600098  3810.600098  3810.600098
# 2024-01-29  3760.600098  3875.000000  3760.550049  3866.649902  3866.649902
#
#              Volume
# Date
# 2024-01-16  1170685
# 2024-01-17   723356
# 2024-01-19  2566367
# 2024-01-22        0
# 2024-01-29   699215

# %%
 # Query for condition where the difference between High and Low is greater than 100
df.query('High-Low>100')
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2023
tail()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2023-10-31  3119.600098  3205.800049  3087.850098  3189.649902  3189.649902
# 2023-11-30  3431.100098  3500.000000  3422.250000  3490.600098  3490.600098
# 2023-12-31  3715.100098  3715.100098  3660.250000  3675.449951  3675.449951
# 2024-01-31  3749.000000  3775.000000  3653.250000  3697.550049  3697.550049
# 2024-02-29  3612.949951  3624.649902  3534.899902  3552.050049  3552.050049
#
#              Volume
# Date
# 2023-10-31  1235478
# 2023-11-30  1480088
# 2023-12-31   709614
# 2024-01-31  1386754
# 2024-02-29  1771380

# %%
df['Close'].iplot(kind='line', title='Line Chart')

# %%
df[-30:].iplot(kind='ohlc', title='Bar Chart')

# %%
 df[-30:].iplot(kind='candle', title='Candle Chart')

# %%
# Use secondary axis
df4[['GS', 'HD']].iplot(secondary_y='HD')

# %%
df4[['GS', 'HD']].iplot(subplots=True)

# %%
# Normalize plot
df4.normalize().iplot()

# %%
# Calculating Log Normal Returns
# Use numpy log function to derive log normal returns
daily_returns = np.log(df4).diff().dropna()

# Display the last five rows of the data frame to check the output
daily_returns.tail()
# Out:
# Ticker          AMGN        GS        HD       MCD       UNH
# Date
# 2024-01-30  0.003726  0.016445  0.003928  0.007973 -0.001845
# 2024-01-31 -0.001145 -0.007420 -0.011661 -0.006572  0.016015
# 2024-02-01  0.032250 -0.000417  0.019944  0.018145 -0.009030
# 2024-02-02 -0.004230  0.010393 -0.007919 -0.003461  0.006074
# 2024-02-05 -0.003782 -0.012557 -0.005868 -0.038014 -0.014351

# %%
# Plot Mean Annual Returns
(daily_returns.mean()*252*100).iplot(kind='bar')

# %%
# Plot Mean Annualized Volatility
(daily_returns.std()*np.sqrt(252)*100).iplot(kind='bar')

# %%
# To calculate 5 days rolling returns, simply sum daily returns for 5 days as log returns are additive
rolling_return = daily_returns.rolling(5).sum().dropna()

# Display the last five rows of the data frame to check the output
rolling_return.head()
# Out:
# Ticker          AMGN        GS        HD       MCD       UNH
# Date
# 2024-01-09  0.032650 -0.011813  0.003212 -0.020990 -0.001800
# 2024-01-10  0.012821  0.000445  0.053361 -0.001020 -0.008132
# 2024-01-11 -0.000231 -0.008391  0.051628  0.008227 -0.010580
# 2024-01-12  0.011518 -0.022744  0.036560  0.015383 -0.029977
# 2024-01-16 -0.024091 -0.021865  0.029732 -0.002779 -0.032911

# %%
# Plot Rolling Returns
rolling_return.iplot(title='5-Days Rolling Returns')

# %%
# Analysing the daily returns data
daily_returns.describe().T
# Out:
#         count      mean       std       min       25%       50%       75%  \
# Ticker
# AMGN     23.0  0.003453  0.011286 -0.014332 -0.004006  0.001975  0.009529
# GS       23.0 -0.000595  0.009922 -0.016907 -0.008026 -0.000716  0.007983
# HD       23.0  0.001249  0.012671 -0.019961 -0.007782  0.000975  0.011430
# MCD      23.0 -0.001651  0.012465 -0.038014 -0.008552 -0.002314  0.006727
# UNH      23.0 -0.003036  0.015432 -0.039404 -0.011690 -0.001357  0.005525
#
#              max
# Ticker
# AMGN    0.032250
# GS      0.016445
# HD      0.030188
# MCD     0.020744
# UNH     0.019668

# %%
# Plot log normal distribution of returns
daily_returns.iplot(kind='histogram', title = 'Histogram of Daily Returns', subplots=True)

# %%
# Plot correlation of returns
daily_returns.corr().iplot(kind='heatmap', title="Correlation Matrix", colorscale="Blues")
